# %% [markdown]
# # Import Library

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Load Data

# %%
df = pd.read_csv('raw-data/usco2015v2.0.csv')
df.head()
# Out:
#   Version 2.0:  Dieter, C.A., Linsey, K.S., Caldwell, R.R., Harris, M.A., Ivahnenko, T.I., Lovelace, J.K., Maupin, M.A., and Barber, N.L., 2018, Estimated use of water in the United States county-level data for 2015 (ver. 2.0, June 2018): U.S. Geological Survey data release, https://doi.org/10.5066/F7TB15V5.  \
# 0                                              STATE
# 1                                                 AL
# 2                                                 AL
# 3                                                 AL
# 4                                                 AL
#
#   Unnamed: 1      Unnamed: 2  Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6  \
# 0  STATEFIPS          COUNTY  COUNTYFIPS       FIPS       YEAR  TP-TotPop
# 1         01  Autauga County         001      01001       2015     55.347
# 2         01  Baldwin County         003      01003       2015    203.709
# 3         01  Barbour County         005      01005       2015     26.489
# ...

# %% [markdown]
# # Change column names

# %% [markdown]
# > Function used to change column names from "Unnamed: n" to their respective column name and to drop row 0

# %%
def preprocess_columns(df):

    # List of all columns
    data_list = ['STATE', 'STATEFIPS', 'COUNTY', 'COUNTYFIPS', 'FIPS', 'YEAR', 'TP-TotPop', 'PS-GWPop', 'PS-SWPop', 'PS-TOPop', 'PS-WGWFr', 'PS-WGWSa',
                 'PS-WGWTo', 'PS-WSWFr', 'PS-WSWSa', 'PS-WSWTo', 'PS-WFrTo', 'PS-WSaTo', 'PS-Wtotl', 'DO-SSPop', 'DO-WGWFr', 'DO-WSWFr', 'DO-WFrTo', 'DO-SSPCp',
                 'DO-PSDel', 'DO-PSPCp', 'DO-WDelv',  'IN-WGWFr', 'IN-WGWSa', 'IN-WGWTo', 'IN-WSWFr', 'IN-WSWSa', 'IN-WSWTo', 'IN-WFrTo', 'IN-WSaTo', 'IN-Wtotl',
                 'IR-WGWFr', 'IR-WSWFr', 'IR-WFrTo', 'IR-RecWW', 'IR-CUsFr', 'IR-IrSpr', 'IR-IrMic', 'IR-IrSur', 'IR-IrTot', 'IC-WGWFr', 'IC-WSWFr', 'IC-WFrTo',
                 'IC-RecWW', 'IC-CUsFr', 'IC-IrSpr', 'IC-IrMic', 'IC-IrSur', 'IC-IrTot', 'IG-WGWFr', 'IG-WSWFr', 'IG-WFrTo', 'IG-RecWW', 'IG-CUsFr', 'IG-IrSpr',
                 'IG-IrMic', 'IG-IrSur', 'IG-IrTot', 'LI-WGWFr', 'LI-WSWFr', 'LI-WFrTo', 'AQ-WGWFr', 'AQ-WGWSa', 'AQ-WGWTo', 'AQ-WSWFr', 'AQ-WSWSa', 'AQ-WSWTo',
                 'AQ-WFrTo', 'AQ-WSaTo', 'AQ-Wtotl', 'MI-WGWFr', 'MI-WGWSa', 'MI-WGWTo', 'MI-WSWFr', 'MI-WSWSa', 'MI-WSWTo', 'MI-WFrTo', 'MI-WSaTo', 'MI-Wtotl', 
                 'PT-WGWFr', 'PT-WGWSa', 'PT-WGWTo', 'PT-WSWFr', 'PT-WSWSa', 'PT-WSWTo', 'PT-WFrTo', 'PT-WSaTo', 'PT-Wtotl', 'PT-RecWW', 'PT-PSDel', 'PT-CUsFr',
                 'PT-CUsSa', 'PT-CUTot', 'PT-Power', 'PO-WGWFr', 'PO-WGWSa', 'PO-WGWTo', 'PO-WSWFr', 'PO-WSWSa', 'PO-WSWTo', 'PO-WFrTo', 'PO-WSaTo', 'PO-Wtotl',
                 'PO-RecWW', 'PO-PSDel', 'PO-CUsFr', 'PO-CUsSa', 'PO-CUTot', 'PO-Power', 'PC-WGWFr', 'PC-WGWSa', 'PC-WGWTo', 'PC-WSWFr', 'PC-WSWSa', 'PC-WSWTo',
                 'PC-WFrTo', 'PC-WSaTo', 'PC-Wtotl', 'PC-RecWW', 'PC-PSDel', 'PC-CUsFr', 'PC-CUsSa', 'PC-CUTot', 'PC-Power', 'TO-WGWFr', 'TO-WGWSa', 'TO-WGWTo',
                 'TO-WSWFr', 'TO-WSWSa', 'TO-WSWTo', 'TO-WFrTo', 'TO-WSaTo', 'TO-Wtotl', 'TO-CUsFrPartial', 'TO-CUsSaPartial', 'TO-CUTotPartial']
    
    print(len(data_list))
    
    # Change column names
    df.columns = data_list

    # Drop the first row
    df = df.drop(0)
    
    return df

# %%
df = preprocess_columns(df)
df.head()
# Out:
# 141
#   STATE STATEFIPS          COUNTY COUNTYFIPS   FIPS  YEAR TP-TotPop PS-GWPop  \
# 1    AL        01  Autauga County        001  01001  2015    55.347       --
# 2    AL        01  Baldwin County        003  01003  2015   203.709       --
# 3    AL        01  Barbour County        005  01005  2015    26.489       --
# 4    AL        01     Bibb County        007  01007  2015    22.583       --
# 5    AL        01   Blount County        009  01009  2015    57.673       --
#
#   PS-SWPop PS-TOPop  ... TO-WGWTo TO-WSWFr TO-WSWSa TO-WSWTo TO-WFrTo  \
# 1       --   48.998  ...    10.69    45.72     0.00    45.72    56.41
# 2       --  174.907  ...    73.38    11.32     0.00    11.32    84.70
# 3       --   24.587  ...     6.06     2.96     0.00     2.96     9.02
# 4       --   20.947  ...     5.67     0.20     0.00     0.20     5.87
# 5       --   44.815  ...     4.64    55.43     0.00    55.43    60.07
#
#   TO-WSaTo TO-Wtotl TO-CUsFrPartial TO-CUsSaPartial TO-CUTotPartial
# ...

# %% [markdown]
# # Condense Features

# %% [markdown]
# > Function to condense groups and drop unnecessary features

# %%
def group_and_drop_columns(df):
    # Group columns
    df['demographic_location_information'] = df[['STATE', 'COUNTY', 'FIPS']].values.tolist()
    df['population'] = df['TP-TotPop']
    df['water_supply'] = df[['PS-GWPop', 'PS-SWPop', 'PS-TOPop']].values.tolist()
    df['water_supply_withdrawals_by_source'] = df[['PS-WGWFr', 'PS-WGWSa', 'PS-WGWTo', 'PS-WSWFr', 'PS-WSWSa', 'PS-WSWTo', 'PS-WFrTo', 'PS-WSaTo', 'PS-Wtotl']].values.tolist()
    df['other_water_usage_categories'] = df[['DO-SSPop', 'DO-WGWFr', 'DO-WSWFr', 'DO-WFrTo', 'DO-SSPCp', 'DO-PSDel', 'DO-PSPCp', 'DO-WDelv']].values.tolist()
    df['industrial_water_usage'] = df[['IN-WGWFr', 'IN-WGWSa', 'IN-WGWTo', 'IN-WSWFr', 'IN-WSWSa', 'IN-WSWTo', 'IN-WFrTo', 'IN-WSaTo', 'IN-Wtotl']].values.tolist()
    df['irrigation_water_usage'] = df[['IR-WGWFr', 'IR-WSWFr', 'IR-WFrTo', 'IR-RecWW', 'IR-CUsFr', 'IR-IrSpr', 'IR-IrMic', 'IR-IrSur', 'IR-IrTot']].values.tolist()
    df['irrigation_crop_usage'] = df[['IC-WGWFr', 'IC-WSWFr', 'IC-WFrTo', 'IC-RecWW', 'IC-CUsFr', 'IC-IrSpr', 'IC-IrMic', 'IC-IrSur', 'IC-IrTot']].values.tolist()
    df['irrigation_golf_usage'] = df[['IG-WGWFr', 'IG-WSWFr', 'IG-WFrTo','IG-RecWW', 'IG-CUsFr', 'IG-IrSpr', 'IG-IrMic', 'IG-IrSur', 'IG-IrTot']].values.tolist()
    df['livestock_water_usage'] = df[['LI-WGWFr', 'LI-WSWFr', 'LI-WFrTo']].values.tolist()
    df['aquaculture_water_usage'] = df[['AQ-WGWFr', 'AQ-WGWSa', 'AQ-WGWTo', 'AQ-WSWFr', 'AQ-WSWSa', 'AQ-WSWTo', 'AQ-WFrTo', 'AQ-WSaTo', 'AQ-Wtotl']].values.tolist()
    df['mining_water_usage'] = df[['MI-WGWFr', 'MI-WGWSa', 'MI-WGWTo', 'MI-WSWFr', 'MI-WSWSa', 'MI-WSWTo', 'MI-WFrTo', 'MI-WSaTo', 'MI-Wtotl']].values.tolist()
    df['thermoelectric_power_generation'] = df[['PT-WGWFr', 'PT-WGWSa', 'PT-WGWTo', 'PT-WSWFr', 'PT-WSWSa', 'PT-WSWTo', 'PT-WFrTo', 'PT-WSaTo', 'PT-Wtotl', 'PT-RecWW', 'PT-PSDel', 'PT-CUsFr', 'PT-CUsSa', 'PT-CUTot', 'PT-Power']].values.tolist()
    df['other_thermoelectric_power_generation'] = df[['PO-WGWFr', 'PO-WGWSa', 'PO-WGWTo', 'PO-WSWFr', 'PO-WSWSa', 'PO-WSWTo', 'PO-WFrTo', 'PO-WSaTo', 'PO-Wtotl', 'PO-RecWW', 'PO-PSDel', 'PO-CUsFr', 'PO-CUsSa', 'PO-CUTot', 'PO-Power']].values.tolist()
    df['recirculating_thermoelectric_power_generation'] = df[['PC-WGWFr', 'PC-WGWSa', 'PC-WGWTo', 'PC-WSWFr', 'PC-WSWSa', 'PC-WSWTo', 'PC-WFrTo', 'PC-WSaTo', 'PC-Wtotl', 'PC-RecWW', 'PC-PSDel', 'PC-CUsFr', 'PC-CUsSa', 'PC-CUTot', 'PC-Power']].values.tolist()
    df['total_water_withdrawals'] = df[['TO-WGWFr', 'TO-WGWSa', 'TO-WGWTo', 'TO-WSWFr', 'TO-WSWSa', 'TO-WSWTo', 'TO-WFrTo', 'TO-WSaTo', 'TO-Wtotl', 'TO-CUsFrPartial', 'TO-CUsSaPartial', 'TO-CUTotPartial']].values.tolist()
    
    # Drop original columns
    df.drop(['STATE', 'STATEFIPS', 'COUNTY', 'COUNTYFIPS', 'FIPS', 'YEAR', 'TP-TotPop', 'PS-GWPop', 'PS-SWPop', 'PS-TOPop', 'PS-WGWFr', 'PS-WGWSa',
                 'PS-WGWTo', 'PS-WSWFr', 'PS-WSWSa', 'PS-WSWTo', 'PS-WFrTo', 'PS-WSaTo', 'PS-Wtotl', 'DO-SSPop', 'DO-WGWFr', 'DO-WSWFr', 'DO-WFrTo', 'DO-SSPCp',
                 'DO-PSDel', 'DO-PSPCp', 'DO-WDelv',  'IN-WGWFr', 'IN-WGWSa', 'IN-WGWTo', 'IN-WSWFr', 'IN-WSWSa', 'IN-WSWTo', 'IN-WFrTo', 'IN-WSaTo', 'IN-Wtotl',
                 'IR-WGWFr', 'IR-WSWFr', 'IR-WFrTo', 'IR-RecWW', 'IR-CUsFr', 'IR-IrSpr', 'IR-IrMic', 'IR-IrSur', 'IR-IrTot', 'IC-WGWFr', 'IC-WSWFr', 'IC-WFrTo',
                 'IC-RecWW', 'IC-CUsFr', 'IC-IrSpr', 'IC-IrMic', 'IC-IrSur', 'IC-IrTot', 'IG-WGWFr', 'IG-WSWFr', 'IG-WFrTo', 'IG-RecWW', 'IG-CUsFr', 'IG-IrSpr',
                 'IG-IrMic', 'IG-IrSur', 'IG-IrTot', 'LI-WGWFr', 'LI-WSWFr', 'LI-WFrTo', 'AQ-WGWFr', 'AQ-WGWSa', 'AQ-WGWTo', 'AQ-WSWFr', 'AQ-WSWSa', 'AQ-WSWTo',
                 'AQ-WFrTo', 'AQ-WSaTo', 'AQ-Wtotl', 'MI-WGWFr', 'MI-WGWSa', 'MI-WGWTo', 'MI-WSWFr', 'MI-WSWSa', 'MI-WSWTo', 'MI-WFrTo', 'MI-WSaTo', 'MI-Wtotl', 
                 'PT-WGWFr', 'PT-WGWSa', 'PT-WGWTo', 'PT-WSWFr', 'PT-WSWSa', 'PT-WSWTo', 'PT-WFrTo', 'PT-WSaTo', 'PT-Wtotl', 'PT-RecWW', 'PT-PSDel', 'PT-CUsFr',
                 'PT-CUsSa', 'PT-CUTot', 'PT-Power', 'PO-WGWFr', 'PO-WGWSa', 'PO-WGWTo', 'PO-WSWFr', 'PO-WSWSa', 'PO-WSWTo', 'PO-WFrTo', 'PO-WSaTo', 'PO-Wtotl',
                 'PO-RecWW', 'PO-PSDel', 'PO-CUsFr', 'PO-CUsSa', 'PO-CUTot', 'PO-Power', 'PC-WGWFr', 'PC-WGWSa', 'PC-WGWTo', 'PC-WSWFr', 'PC-WSWSa', 'PC-WSWTo',
                 'PC-WFrTo', 'PC-WSaTo', 'PC-Wtotl', 'PC-RecWW', 'PC-PSDel', 'PC-CUsFr', 'PC-CUsSa', 'PC-CUTot', 'PC-Power', 'TO-WGWFr', 'TO-WGWSa', 'TO-WGWTo',
                 'TO-WSWFr', 'TO-WSWSa', 'TO-WSWTo', 'TO-WFrTo', 'TO-WSaTo', 'TO-Wtotl', 'TO-CUsFrPartial', 'TO-CUsSaPartial', 'TO-CUTotPartial'], axis=1, inplace=True)
    
    # Replace -- with 0s
    df.replace('--', 0, inplace=True)
    
    return df

# %%
#df = group_and_drop_columns(df)
#df.head()
# Out:
#   STATE STATEFIPS          COUNTY COUNTYFIPS   FIPS  YEAR TP-TotPop PS-GWPop  \
# 1    AL        01  Autauga County        001  01001  2015    55.347       --
# 2    AL        01  Baldwin County        003  01003  2015   203.709       --
# 3    AL        01  Barbour County        005  01005  2015    26.489       --
# 4    AL        01     Bibb County        007  01007  2015    22.583       --
# 5    AL        01   Blount County        009  01009  2015    57.673       --
#
#   PS-SWPop PS-TOPop  ... TO-WGWTo TO-WSWFr TO-WSWSa TO-WSWTo TO-WFrTo  \
# 1       --   48.998  ...    10.69    45.72     0.00    45.72    56.41
# 2       --  174.907  ...    73.38    11.32     0.00    11.32    84.70
# 3       --   24.587  ...     6.06     2.96     0.00     2.96     9.02
# 4       --   20.947  ...     5.67     0.20     0.00     0.20     5.87
# 5       --   44.815  ...     4.64    55.43     0.00    55.43    60.07
#
#   TO-WSaTo TO-Wtotl TO-CUsFrPartial TO-CUsSaPartial TO-CUTotPartial
# ...

# %% [markdown]
# # Save Data as CSV File

# %%
df.to_csv('clean-data/usco2015v2.0_clean.csv', index=False)
