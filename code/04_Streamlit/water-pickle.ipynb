# %%
# Imports
import pandas as pd
import pickle

from sklearn.linear_model import LinearRegression
from sklearn import metrics

# %%
# Import data
df = pd.read_csv('./clean-data/usco2015v2.0_clean.csv')
df.head()
# Out:
#     demographic_location_information  population             water_supply  \
# 0  ['AL', 'Autauga County', '01001']      55.347   ['--', '--', '48.998']
# 1  ['AL', 'Baldwin County', '01003']     203.709  ['--', '--', '174.907']
# 2  ['AL', 'Barbour County', '01005']      26.489   ['--', '--', '24.587']
# 3     ['AL', 'Bibb County', '01007']      22.583   ['--', '--', '20.947']
# 4   ['AL', 'Blount County', '01009']      57.673   ['--', '--', '44.815']
#
#                   water_supply_withdrawals_by_source  \
# 0  ['3.64', '0.00', '3.64', '0.00', '0.00', '0.00...
# 1  ['23.67', '0.00', '23.67', '0.00', '0.00', '0....
# 2  ['3.23', '0.00', '3.23', '0.00', '0.00', '0.00...
# 3  ['5.18', '0.00', '5.18', '0.00', '0.00', '0.00...
# 4  ['2.78', '0.00', '2.78', '54.08', '0.00', '54....
#
#          other_water_usage_categories  \
# 0   ['6.349', '0.38', '0.00', '0.38']
# 1  ['28.802', '2.14', '0.00', '2.14']
# 2   ['1.902', '0.12', '0.00', '0.12']
# 3   ['1.636', '0.16', '0.00', '0.16']
# ...

# %%
# Shape
df.shape
# Out:
# (3223, 14)

# %%
# Create a 'model'
model_0 = df['population'].mean()

# %%
# Write the pickled value to disk
with open('./model_0.pkl', 'wb') as pickle_out:
    pickle_out = pickle.dump(model_0, pickle_out)

# %%
# Open the pickled value
with open('./model_0.pkl', 'rb') as pickle_in:
    zero_model = pickle.load(pickle_in)
    
zero_model
# Out:
# 100.84358175612783
